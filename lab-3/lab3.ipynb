# %% [markdown]
# # Лабораторная работа №3. Использование механизмов внимания в нейронных сетях
#
# Выполнил Сердюков Матвей, ББМО-01-23

# %% [markdown]
# Загрузка модели VGG16, переключение активации `softmax` на линейную

# %%
from keras.applications import VGG16
from vis.utils import utils
from keras import activations

# Build the VGG16 network with ImageNet weights
model = VGG16(weights='imagenet', include_top=True)

# Utility to search for layer index by name. 
# Alternatively we can specify this as -1 since it corresponds to the last layer.
layer_idx = utils.find_layer_idx(model, 'predictions')

# Swap softmax with linear
model.layers[layer_idx].activation = activations.linear
model = utils.apply_modifications(model)
# Out:
# I0000 00:00:1733753109.647156    6135 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1756 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 20s 0us/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2024-12-09 17:05:43.332728: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:497] Allocator (GPU_0_bfc) ran out of memory trying to allocate 392.00MiB (rounded to 411041792)requested by op AddV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-12-09 17:05:43.333000: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1053] BFCAllocator dump for GPU_0_bfc
# 2024-12-09 17:05:43.333116: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (256): 	Total Chunks: 31, Chunks in use: 31. 7.8KiB allocated for chunks. 7.8KiB in use in bin. 1.1KiB client-requested in use in bin.
# 2024-12-09 17:05:43.333147: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (512): 	Total Chunks: 5, Chunks in use: 4. 2.5KiB allocated for chunks. 2.0KiB in use in bin. 2.0KiB client-requested in use in bin.
# 2024-12-09 17:05:43.333162: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (1024): 	Total Chunks: 7, Chunks in use: 7. 7.2KiB allocated for chunks. 7.2KiB in use in bin. 7.0KiB client-requested in use in bin.
# 2024-12-09 17:05:43.333179: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (2048): 	Total Chunks: 12, Chunks in use: 12. 24.2KiB allocated for chunks. 24.2KiB in use in bin. 24.0KiB client-requested in use in bin.
# 2024-12-09 17:05:43.333195: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (4096): 	Total Chunks: 4, Chunks in use: 3. 22.5KiB allocated for chunks. 18.5KiB in use in bin. 17.4KiB client-requested in use in bin.
# 2024-12-09 17:05:43.333260: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-09 17:05:43.333287: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (16384): 	Total Chunks: 2, Chunks in use: 2. 32.0KiB allocated for chunks. 32.0KiB in use in bin. 32.0KiB client-requested in use in bin.
# 2024-12-09 17:05:43.333302: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-09 17:05:43.333314: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-12-09 17:05:43.333332: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (131072): 	Total Chunks: 2, Chunks in use: 2. 381.8KiB allocated for chunks. 381.8KiB in use in bin. 288.0KiB client-requested in use in bin.
# 2024-12-09 17:05:43.333347: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (262144): 	Total Chunks: 4, Chunks in use: 2. 1.27MiB allocated for chunks. 720.0KiB in use in bin. 576.0KiB client-requested in use in bin.
# 2024-12-09 17:05:43.333360: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (524288): 	Total Chunks: 2, Chunks in use: 2. 1.12MiB allocated for chunks. 1.12MiB in use in bin. 1.12MiB client-requested in use in bin.
# 2024-12-09 17:05:43.333373: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin (1048576): 	Total Chunks: 5, Chunks in use: 2. 6.59MiB allocated for chunks. 3.09MiB in use in bin. 2.25MiB client-requested in use in bin.
# 2024-12-09 17:05:43.333385: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1060] Bin
I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 1280 totalling 1.2KiB
# 2024-12-09 17:05:43.334850: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 11 Chunks of size 2048 totalling 22.0KiB
# 2024-12-09 17:05:43.334859: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 2304 totalling 2.2KiB
# 2024-12-09 17:05:43.334868: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 5120 totalling 5.0KiB
# 2024-12-09 17:05:43.334877: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 2 Chunks of size 6912 totalling 13.5KiB
# 2024-12-09 17:05:43.334886: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 2 Chunks of size 16384 totalling 32.0KiB
# 2024-12-09 17:05:43.334895: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 147456 totalling 144.0KiB
# 2024-12-09 17:05:43.334904: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 243456 totalling 237.8KiB
# 2024-12-09 17:05:43.334915: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 294912 totalling 288.0KiB
# 2024-12-09 17:05:43.334923: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 442368 totalling 432.0KiB
# 2024-12-09 17:05:43.334932: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 2 Chunks of size 589824 totalling 1.12MiB
# 2024-12-09 17:05:43.334940: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 1179648 totalling 1.12MiB
# 2024-12-09 17:05:43.334949: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 2064384 totalling 1.97MiB
# 2024-12-09 17:05:43.334957: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 4 Chunks of size 2359296 totalling 9.00MiB
# 2024-12-09 17:05:43.334966: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 2 Chunks of size 4718592 totalling 9.00MiB
# 2024-12-09 17:05:43.334975: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 9 Chunks of size 9437184 totalling 81.00MiB
# 2024-12-09 17:05:43.334984: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 2 Chunks of size 16384000 totalling 31.25MiB
# 2024-12-09 17:05:43.334993: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 101449728 totalling 96.75MiB
# 2024-12-09 17:05:43.335002: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 2 Chunks of size 411041792 totalling 784.00MiB
# 2024-12-09 17:05:43.335011: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] 1 Chunks of size 444071936 totalling 423.50MiB
# 2024-12-09 17:05:43.335020: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1121] Sum Total of in-use chunks: 1.41GiB
# 2024-12-09 17:05:43.335029: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1123] Total bytes in pool: 1841561600 memory_limit_: 1841561600 available bytes: 0 curr_region_allocation_bytes_: 3683123200
# 2024-12-09 17:05:43.335048: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1128] Stats:
# Limit:                      1841561600
# InUse:                      1509828096
# MaxInUse:                   1509828352
# NumAllocs:                         385
# MaxAllocSize:                444071936
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-12-09 17:05:43.335068: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:508] ******************************************************************************x*****________________
# 2024-12-09 17:05:43.335137: W tensorflow/core/framework/op_kernel.cc:1829] RESOURCE_EXHAUSTED: failed to allocate memory
# 2024-12-09 17:05:43.335220: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: failed to allocate memory
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[2], line 14
#      12 # Swap softmax with linear
#      13 model.layers[layer_idx].activation = activations.linear
# ---> 14 model = utils.apply_modifications(model)
#
# File ~/.virtualenvs/aszii-lab3/lib/python3.12/site-packages/vis/utils/utils.py:124, in apply_modifications(model)
#     122 try:
#     123     model.save(model_path)
# --> 124     return load_model(model_path)
#     125 finally:
#     126     os.remove(model_path)
#
# File ~/.virtualenvs/aszii-lab3/lib/python3.12/site-packages/keras/src/saving/saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File ~/.virtualenvs/aszii-lab3/lib/python3.12/site-packages/keras/src/legacy/saving/legacy_h5_format.py:133, in load_model_from_hdf5(filepath, custom_objects, compile)
#     130 model_config = json_utils.decode(model_config)
#     132 with saving_options.keras_option_scope(use_legacy_config=True):
# --> 133     model = saving_utils.model_from_config(
#     134         model_config, custom_objects=custom_objects
#     135     )
#     137     # set weights
#     138     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File ~/.virtualenvs/aszii-lab3/lib/python3.12/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/.virtualenvs/aszii-lab3/lib/python3.12/site-packages/keras/src/legacy/saving/serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~/.virtualenvs/aszii-lab3/lib/python3.12/site-packages/keras/src/models/model.py:527, in Model.from_config(cls, config, custom_objects)
#     522 if is_functional_config and revivable_as_functional:
#     523     # Revive Functional model
#     524     # (but not Functional subclasses with a custom __init__)
#     525     from keras.src.models.functional import functional_from_config
# --> 527     return functional_from_config(
#     528         cls, config, custom_objects=custom_objects
#     529     )
#     531 # Either the model has a custom __init__, or the config
#     532 # does not contain all the information necessary to
#     533 # revive a Functional model. This happens when the user creates
#    (...)
#     536 # In this case, we fall back to provide all config into the
#     537 # constructor of the class.
#     538 try:
#
# File ~/.virtualenvs/aszii-lab3/lib/python3.12/site-packages/keras/src/models/functional.py:565, in functional_from_config(cls, config, custom_objects)
#     563 node_data = node_data_list[node_index]
#     564 try:
# --> 565     process_node(layer, node_data)
#     567 # If the node does not have all inbound layers
#     568 # available, stop processing and continue later
#     569 except IndexError:
#
# File ~/.virtualenvs/aszii-lab3/lib/python3.12/site-packages/keras/src/models/functional.py:500, in functional_from_config.<locals>.process_node(layer, node_data)
#     497 args, kwargs = deserialize_node(node_data, created_layers)
#     498 # Call layer on its inputs, thus creating the node
#     499 # and building the layer if needed.
# --> 500 layer(*args, **kwargs)
#
# File ~/.virtualenvs/aszii-lab3/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.virtualenvs/aszii-lab3/lib/python3.12/site-packages/keras/src/backend/tensorflow/random.py:34, in uniform(shape, minval, maxval, dtype, seed)
#      32 dtype = dtype or floatx()
#      33 seed = _cast_seed(draw_seed(seed))
# ---> 34 return tf.random.stateless_uniform(
#      35     shape=shape,
#      36     minval=tf.cast(minval, dtype),
#      37     maxval=tf.cast(maxval, dtype),
#      38     dtype=dtype,
#      39     seed=seed,
#      40 )
#
# ResourceExhaustedError: {{function_node __wrapped__AddV2_device_/job:localhost/replica:0/task:0/device:GPU:0}} failed to allocate memory [Op:AddV2] name:
